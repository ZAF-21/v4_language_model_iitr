# %% [markdown]
# https://www.youtube.com/watch?v=Tsvxx-GGlTg

# %% [markdown]
# https://www.csfieldguide.org.nz/en/interactives/rgb-mixer/

# %% [markdown]
# https://www.csfieldguide.org.nz/en/interactives/pixel-viewer/

# %% [markdown]
# https://ezyang.github.io/convolution-visualizer/

# %%
# !gdown 1ViZ9V5y5s9IRazM5ZaoWd_7p8QpJIJ92 -O fluffy.jpeg
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ViZ9V5y5s9IRazM5ZaoWd_7p8QpJIJ92
# To: /content/fluffy.jpeg
# 100% 58.7k/58.7k [00:00<00:00, 104MB/s]

# %%
import matplotlib.pyplot as plt

# %%
# show fluffy.jpeg
img = plt.imread('fluffy.jpeg')
plt.imshow(img)
# plt.axis('off')  # Hide axes
plt.show()

# %%
import numpy as np
fluffy=np.array(plt.imread('fluffy.jpeg'))
fluffy.shape # Height x Width * channels
# Out:
# (564, 564, 3)

# %%
plt.imshow(fluffy[20:250,120:420,:])

# %%
plt.imshow(fluffy[:,::-1,:])

# %%
plt.imshow(fluffy[::-1,:,:])

# %%
plt.imshow(fluffy[::5, ::5, :])

# %%
plt.imshow(fluffy[::10, ::10, :])

# %%
fluffy_negative_sorry=255-fluffy

plt.imshow(fluffy_negative_sorry)

# %%
fluffy_g = fluffy.copy()
fluffy_g[:,:,(0,2)] = 0
plt.imshow(fluffy_g)
